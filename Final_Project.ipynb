# %%
def simple_calculator():
    while True:
        try:
            num_calculations = int(input("How many calculations do you want to perform? "))
            if num_calculations <= 0:
                print("Please enter a positive number of calculations.")
            else:
                break
        except ValueError:
            print("Invalid input. Please enter a whole number.")

    for i in range(num_calculations):
        print(f"\n--- Calculation {i + 1} of {num_calculations} ---")

        while True:
            try:
                num1 = float(input("Enter the first number: "))
                break
            except ValueError:
                print("Invalid input. Please enter a valid number.")

        while True:
            try:
                num2 = float(input("Enter the second number: "))
                break
            except ValueError:
                print("Invalid input. Please enter a valid number.")

        operator = input("Enter an operator (+, -, *, /): ")

        result = None
        if operator == '+':
            result = num1 + num2
        elif operator == '-':
            result = num1 - num2
        elif operator == '*':
            result = num1 * num2
        elif operator == '/':
            if num2 == 0:
                print("Error: Division by zero is not allowed.")
            else:
                result = num1 / num2
        else:
            print("Error: Invalid operator. Please use +, -, *, or /.")

        if result is not None:
            print(f"Result: {num1} {operator} {num2} = {result}")

# Run the calculator
simple_calculator()
# Out:
# How many calculations do you want to perform? 2
#
# --- Calculation 1 of 2 ---
# Enter the first number: 10
# Enter the second number: 50.2
# Enter an operator (+, -, *, /): +
# Result: 10.0 + 50.2 = 60.2
#
# --- Calculation 2 of 2 ---
# Enter the first number: 52.453
# Enter the second number: 23.53
# Enter an operator (+, -, *, /): *
# Result: 52.453 * 23.53 = 1234.21909
